# %%
import os

# 获取当前工作目录
directory_path = os.getcwd()

# 输出结果
print("当前工作目录:", directory_path)
# Out:
# 当前工作目录: /content

# %%
import cv2
import matplotlib.pyplot as plt

# 加载图片路径
image_path = "/content/Unknown.jpeg"  # 根据你的文件路径调整

# 读取图片（以BGR格式）
image = cv2.imread(image_path)

# 检查图片是否加载成功
if image is not None:
    print("图片加载成功！")
    # 转换 BGR 到 RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # 使用 plt 显示图片
    plt.imshow(image_rgb)
    plt.axis("off")  # 隐藏坐标轴
    plt.show()
else:
    print("图片加载失败，请检查路径或文件是否存在！")
# Out:
# 图片加载成功！
